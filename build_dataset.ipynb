# %%
# %pip install pychesscom pandas
# Out:
# Requirement already satisfied: pychesscom in /opt/homebrew/lib/python3.10/site-packages (0.1.3)
# Collecting pandas
#   Downloading pandas-1.4.4-cp310-cp310-macosx_11_0_arm64.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.10/site-packages (from pychesscom) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/monk/Library/Python/3.10/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (1.23.3)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /Users/monk/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/monk/Library/Python/3.10/lib/python/site-packages (from aiohttp->pychesscom) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp->pychesscom) (1.2.0)
# Requirement already satisfied: idna>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp->pychesscom) (3.4)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.4 pytz-2022.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
from datetime import datetime

from pychesscom import ChessComClient


client = ChessComClient()

# %%
## get all WGM usernames

wgm_usernames_response = await client.player.get_titled_players('GM')
wgm_usernames = wgm_usernames_response.content['players']

# %%
## new month details
year = 2021
month = 2

game_id = []
game_url = []
pgn = []
time_control = []
end_time = []
rated = []
time_class = []
rules = []
wgm_username = []
white_username = []
white_rating = []
white_result = []
black_username = []
black_rating = []
black_result = []

## iterating over WGM usernames
for username in wgm_usernames[:50]:
  print(username)
  wgm_games_response = await client.player.get_games(username, year, month)
  wgm_games = wgm_games_response.content['games']

  # iterating over WGM's games
  if len(wgm_games) > 0:
      for game in wgm_games:
          # add dataset feature values
          if 'pgn' not in game.keys():
              game['pgn'] = ''

          game_id.append(re.sub('https://www.chess.com/live/game/', '', game['url']))
          game_url.append(game['url'])
          pgn.append(game['pgn'])
          time_control.append(game['time_control'])
          end_time.append(datetime.fromtimestamp(int(game['end_time'])).strftime('%Y-%m-%d %H:%M:%S'))
          rated.append(game['rated'])
          time_class.append(game['time_class'])
          rules.append(game['rules'])
          wgm_username.append(username)
          white_username.append(game['white']['username'])
          white_rating.append(game['white']['rating'])
          white_result.append(game['white']['result'])
          black_username.append(game['black']['username'])
          black_rating.append(game['black']['rating'])
          black_result.append(game['black']['result'])

new_data = pd.DataFrame({
    'game_id': game_id,
    'game_url': game_url,
    'pgn': pgn,
    'time_control': time_control,
    'end_time': end_time,
    'rated': rated,
    'time_class': time_class,
    'rules': rules,
    'wgm_username': wgm_username,
    'white_username': white_username,
    'white_rating': white_rating,
    'white_result': white_result,
    'black_username': black_username,
    'black_rating': black_rating,
    'black_result': black_result
})

new_data
# Out:
# 123lt
# 124chess
# 1977ivan
# 1stsecond
# 4thd-alpeacefulmoon
# 64aramis64
# 64arthos64
# 64atilla64
# 64dartagnan64
# 64genghis64
# 64leonidas64
# 64porthos64
# 64pyrrhus64
# 731291
# a-adly
# a-fier
# abasovn
# abhidabhi
# abhijeetgupta
# abhijeetgupta1016
# abhijeetonyoutube
# abhyak
# absentzest
# abykhovsky
# actorxu
# adaro
# adham_fawzy
# adiosabu
# afgano29
# aggy67
# agser
# airgun1
# aivanov-ne
# akobian-sea
# akobian-stl
# akshatchandra
# akshayraj_kore
# alefedorov
# aleksa74
# aleksandrovaleksei
# aleksey_sorokin
# alexander-evdokimov
# alexanderl
# alexander_donchenko
# alexander_moskalenko
# alexander_zubov
# alexandr_predke
# alexchess1062
# alexchess1984
# alexcolovic
#                                          game_id  \
# 0     https://www.chess.com/game/live/6423671260
# 1     https://www.chess.com/game/live/6423766404
# 2     https://www.chess.com/game/live/6543549448
# 3     https://www.chess.com/game/live/6543707368
# 4     https://www.chess.com/game/live/6543860094
# ...                                          ...
# 2956  https://www.chess.com/game/live/6503890798
# 2957  https://www.chess.com/game/live/6504006015
# 2958  https://www.chess.com/game/live/6504109795
# 2959  https://www.chess.com/game/live/6504220870
# 2960  https://www.chess.com/game/live/6504381571
#
#                                         game_url  \
# 0     https://www.chess.com/game/live/6423671260
# 1     https://www.chess.com/game/live/6423766404
# 2     https://www.chess.com/game/live/6543549448
# 3     https://www.chess.com/game/live/6543707368
# 4     https://www.chess.com/game/live/6543860094
# ...                                          ...
# 2956  https://www.chess.com/game/live/6503890798
# 2957  https://www.chess.com/game/live/6504006015
# 2958  https://www.chess.com/game/live/6504109795
# 2959  https://www.chess.com/game/live/6504220870
# 2960  https://www.chess.com/game/live/6504381571
#
#                                                     pgn time_control  \
# 0     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 1     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+2
# 2     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# 3     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# 4     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# ...                                                 ...          ...
# 2956  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 2957  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 2958  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 2959  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 2960  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
#
#                  end_time  rated time_class  rules   wgm_username  \
# 0     2021-02-02 08:58:49   True      blitz  chess       124chess
# 1     2021-02-02 09:20:27  False      blitz  chess       124chess
# 2     2021-02-13 14:21:48   True      rapid  chess       124chess
# 3     2021-02-13 14:43:09  False      rapid  chess       124chess
# 4     2021-02-13 14:59:01  False      rapid  chess       124chess
# ...                   ...    ...        ...    ...            ...
# 2956  2021-02-09 20:58:28   True      blitz  chess  alexchess1984
# 2957  2021-02-09 21:07:05   True      blitz  chess  alexchess1984
# 2958  2021-02-09 21:19:39   True      blitz  chess  alexchess1984
# 2959  2021-02-09 21:27:01   True      blitz  chess  alexchess1984
# 2960  2021-02-09 21:44:39   True      blitz  chess  alexchess1984
#
#      white_username  white_rating white_result black_username  black_rating  \
# 0          124chess          2713   repetition   Semen_Khanin          2800
# 1          124chess          2713          win       MutovinE          2280
# 2       leejunhyeok          2315     resigned       124chess          2244
# 3          124chess          2244          win    leejunhyeok          2315
# 4       leejunhyeok          2315   repetition       124chess          2244
# ...             ...           ...          ...            ...           ...
# 2956  Alexchess1984          2707   repetition   TigrVShlyape          2840
# 2957  Alexchess1984          2719          win      AryanTari          2887
# 2958     Angry_Twin          2835   checkmated  Alexchess1984          2730
# 2959  Alexchess1984          2725     resigned     rpragchess          2874
# 2960        DrVelja          2834          win  Alexchess1984          2719
#
#      black_result
# 0      repetition
# 1         timeout
# 2             win
# 3        resigned
# 4      repetition
# ...           ...
# 2956   repetition
# 2957      timeout
# 2958          win
# 2959          win
# 2960     resigned
#
# [2961 rows x 15 columns]

# %%
## current dataset
current_dataset = pd.read_csv('games.csv')

# %%
updated_dataset = pd.concat([current_dataset, new_data], ignore_index = True)

updated_dataset
# Out:
#                                          game_id  \
# 0     https://www.chess.com/game/live/6423671260
# 1     https://www.chess.com/game/live/6423766404
# 2     https://www.chess.com/game/live/6543549448
# 3     https://www.chess.com/game/live/6543707368
# 4     https://www.chess.com/game/live/6543860094
# ...                                          ...
# 3040  https://www.chess.com/game/live/6503890798
# 3041  https://www.chess.com/game/live/6504006015
# 3042  https://www.chess.com/game/live/6504109795
# 3043  https://www.chess.com/game/live/6504220870
# 3044  https://www.chess.com/game/live/6504381571
#
#                                         game_url  \
# 0     https://www.chess.com/game/live/6423671260
# 1     https://www.chess.com/game/live/6423766404
# 2     https://www.chess.com/game/live/6543549448
# 3     https://www.chess.com/game/live/6543707368
# 4     https://www.chess.com/game/live/6543860094
# ...                                          ...
# 3040  https://www.chess.com/game/live/6503890798
# 3041  https://www.chess.com/game/live/6504006015
# 3042  https://www.chess.com/game/live/6504109795
# 3043  https://www.chess.com/game/live/6504220870
# 3044  https://www.chess.com/game/live/6504381571
#
#                                                     pgn time_control  \
# 0     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 1     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+2
# 2     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# 3     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# 4     [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        600+3
# ...                                                 ...          ...
# 3040  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 3041  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 3042  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 3043  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
# 3044  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        180+1
#
#                  end_time  rated time_class  rules   wgm_username  \
# 0     2021-02-02 08:58:49   True      blitz  chess       124chess
# 1     2021-02-02 09:20:27  False      blitz  chess       124chess
# 2     2021-02-13 14:21:48   True      rapid  chess       124chess
# 3     2021-02-13 14:43:09  False      rapid  chess       124chess
# 4     2021-02-13 14:59:01  False      rapid  chess       124chess
# ...                   ...    ...        ...    ...            ...
# 3040  2021-02-09 20:58:28   True      blitz  chess  alexchess1984
# 3041  2021-02-09 21:07:05   True      blitz  chess  alexchess1984
# 3042  2021-02-09 21:19:39   True      blitz  chess  alexchess1984
# 3043  2021-02-09 21:27:01   True      blitz  chess  alexchess1984
# 3044  2021-02-09 21:44:39   True      blitz  chess  alexchess1984
#
#      white_username  white_rating white_result black_username  black_rating  \
# 0          124chess          2713   repetition   Semen_Khanin          2800
# 1          124chess          2713          win       MutovinE          2280
# 2       leejunhyeok          2315     resigned       124chess          2244
# 3          124chess          2244          win    leejunhyeok          2315
# 4       leejunhyeok          2315   repetition       124chess          2244
# ...             ...           ...          ...            ...           ...
# 3040  Alexchess1984          2707   repetition   TigrVShlyape          2840
# 3041  Alexchess1984          2719          win      AryanTari          2887
# 3042     Angry_Twin          2835   checkmated  Alexchess1984          2730
# 3043  Alexchess1984          2725     resigned     rpragchess          2874
# 3044        DrVelja          2834          win  Alexchess1984          2719
#
#      black_result
# 0      repetition
# 1         timeout
# 2             win
# 3        resigned
# 4      repetition
# ...           ...
# 3040   repetition
# 3041      timeout
# 3042          win
# 3043          win
# 3044     resigned
#
# [3045 rows x 15 columns]

# %%
updated_dataset.to_csv('games.csv', index = False)
